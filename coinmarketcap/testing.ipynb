# %%
from coinmarketcapapi import CoinMarketCapAPI, CoinMarketCapAPIError

# %%
cmc = CoinMarketCapAPI("f13a5b69-a336-4a1f-ba41-b35d6ff62f24")
r = cmc.cryptocurrency_info(symbol='MATIC')
r.data
# Out:
# {'MATIC': {'id': 3890,
#   'name': 'Polygon',
#   'symbol': 'MATIC',
#   'category': 'coin',
#   'description': 'Polygon (MATIC) is a cryptocurrency . Polygon has a current supply of 10,000,000,000 with 8,042,124,673.28493 in circulation. The last known price of Polygon is 0.7959128 USD and is up 1.75 over the last 24 hours. It is currently trading on 462 active market(s) with $528,414,701.15 traded over the last 24 hours. More information can be found at https://polygon.technology/.',
#   'slug': 'polygon',
#   'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/3890.png',
#   'subreddit': '0xPolygon',
#   'notice': '',
#   'tags': ['platform',
#    'enterprise-solutions',
#    'scaling',
#    'state-channel',
#    'coinbase-ventures-portfolio',
#    'binance-launchpad',
#    'binance-labs-portfolio',
#    'polygon-ecosystem',
#    'moonriver-ecosystem',
#    'injective-ecosystem',
#    'bnb-chain'],
#   'tag-names': ['Platform',
#    'Enterprise Solutions',
# ...

# %%
json_data = {}
a = {'APE': {'id': 18876, 'name': 'ApeCoin', 'symbol': 'APE', 'category': 'token', 'description': 'ApeCoin (APE) is a cryptocurrency launched in 2022and operates on the Ethereum platform. ApeCoin has a current supply of 1,000,000,000 with 306,875,000 in circulation. The last known price of ApeCoin is 5.15831029 USD and is down -2.21 over the last 24 hours. It is currently trading on 188 active market(s) with $334,447,638.09 traded over the last 24 hours. More information can be found at http://apecoin.com/.', 'slug': 'apecoin-ape', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/18876.png', 'subreddit': '', 'notice': '', 'tags': ['collectibles-nfts', 'content-creation', 'gaming', 'entertainment', 'dao', 'governance', 'metaverse', 'animoca-brands-portfolio'], 'tag-names': ['Collectibles & NFTs', 'Content Creation', 'Gaming', 'Entertainment', 'DAO', 'Governance', 'Metaverse', 'Animoca Brands Portfolio'], 'tag-groups': ['CATEGORY', 'INDUSTRY', 'INDUSTRY', 'INDUSTRY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY'], 'urls': {'website': ['http://apecoin.com/'], 'twitter': ['https://twitter.com/apecoin'], 'message_board': [], 'chat': ['https://forum.apecoin.com'], 'facebook': [], 'explorer': ['https://etherscan.io/token/0x4d224452801aced8b2f0aebe155379bb5d594381'], 'reddit': [], 'technical_doc': [], 'source_code': [], 'announcement': []}, 'platform': {'id': '1027', 'name': 'Ethereum', 'slug': 'ethereum', 'symbol': 'ETH', 'token_address': '0x4d224452801aced8b2f0aebe155379bb5d594381'}, 'date_added': '2022-03-17T12:26:36.000Z', 'twitter_username': 'apecoin', 'is_hidden': 0, 'date_launched': '2022-03-16T00:00:00.000Z', 'contract_address': [{'contract_address': '0x4d224452801aced8b2f0aebe155379bb5d594381', 'platform': {'name': 'Ethereum', 'coin': {'id': '1027', 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum'}}}], 'self_reported_circulating_supply': 314218750, 'self_reported_tags': ['Medium of Exchange', 'Collectibles & NFTs', 'Gaming', 'Entertainment', 'DAO', 'Ethereum Ecosystem', 'Web3'], 'self_reported_market_cap': 1625327743.8451974}}

# %%
json_data.update(a)

# %%
b = {'MATIC': {'id': 3890, 'name': 'Polygon', 'symbol': 'MATIC', 'category': 'coin', 'description': 'Polygon (MATIC) is a cryptocurrency . Polygon has a current supply of 10,000,000,000 with 8,042,124,673.28493 in circulation. The last known price of Polygon is 0.7959128 USD and is up 1.75 over the last 24 hours. It is currently trading on 462 active market(s) with $528,414,701.15 traded over the last 24 hours. More information can be found at https://polygon.technology/.', 'slug': 'polygon', 'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/3890.png', 'subreddit': '0xPolygon', 'notice': '', 'tags': ['platform', 'enterprise-solutions', 'scaling', 'state-channel', 'coinbase-ventures-portfolio', 'binance-launchpad', 'binance-labs-portfolio', 'polygon-ecosystem', 'moonriver-ecosystem', 'injective-ecosystem', 'bnb-chain'], 'tag-names': ['Platform', 'Enterprise Solutions', 'Scaling', 'State Channel', 'Coinbase Ventures Portfolio', 'Binance Launchpad', 'Binance Labs Portfolio', 'Polygon Ecosystem', 'Moonriver Ecosystem', 'Injective Ecosystem', 'BNB Chain'], 'tag-groups': ['CATEGORY', 'INDUSTRY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'CATEGORY', 'PLATFORM', 'CATEGORY', 'PLATFORM', 'PLATFORM'], 'urls': {'website': ['https://polygon.technology/'], 'twitter': ['https://twitter.com/0xPolygon'], 'message_board': ['https://blog.polygon.technology/'], 'chat': ['https://t.me/polygonofficial', 'https://open.kakao.com/o/gUpfOhmb'], 'facebook': [], 'explorer': ['https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0', 'https://ethplorer.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0', 'https://explorer.solana.com/address/C7NNPWuZCNjZBfW5p6JvGsR8pUdsRpEdP1ZAhnoDwj7h'], 'reddit': ['https://reddit.com/r/0xPolygon'], 'technical_doc': ['https://polygon.technology/papers/'], 'source_code': ['https://github.com/maticnetwork/contracts'], 'announcement': []}, 'platform': {'id': '1027', 'name': 'Ethereum', 'slug': 'ethereum', 'symbol': 'ETH', 'token_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'}, 'date_added': '2019-04-28T00:00:00.000Z', 'twitter_username': '0xPolygon', 'is_hidden': 0, 'date_launched': None, 'contract_address': [{'contract_address': '0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0', 'platform': {'name': 'Ethereum', 'coin': {'id': '1027', 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum'}}}, {'contract_address': '0xcc42724c6683b7e57334c4e856f4c9965ed682bd', 'platform': {'name': 'BNB Smart Chain (BEP20)', 'coin': {'id': '1839', 'name': 'BNB', 'symbol': 'BNB', 'slug': 'bnb'}}}, {'contract_address': '0x0000000000000000000000000000000000001010', 'platform': {'name': 'Polygon', 'coin': {'id': '3890', 'name': 'Polygon', 'symbol': 'MATIC', 'slug': 'polygon'}}}, {'contract_address': 'C7NNPWuZCNjZBfW5p6JvGsR8pUdsRpEdP1ZAhnoDwj7h', 'platform': {'name': 'Solana', 'coin': {'id': '5426', 'name': 'Solana', 'symbol': 'SOL', 'slug': 'solana'}}}, {'contract_address': '0x3405a1bd46b85c5c029483fbecf2f3e611026e45', 'platform': {'name': 'Moonbeam', 'coin': {'id': '6836', 'name': 'Moonbeam', 'symbol': 'GLMR', 'slug': 'moonbeam'}}}], 'self_reported_circulating_supply': None, 'self_reported_tags': None, 'self_reported_market_cap': None}}

# %%
json_data.update(b)

# %%
json_data
# Out:
# {'APE': {'id': 18876,
#   'name': 'ApeCoin',
#   'symbol': 'APE',
#   'category': 'token',
#   'description': 'ApeCoin (APE) is a cryptocurrency launched in 2022and operates on the Ethereum platform. ApeCoin has a current supply of 1,000,000,000 with 306,875,000 in circulation. The last known price of ApeCoin is 5.15831029 USD and is down -2.21 over the last 24 hours. It is currently trading on 188 active market(s) with $334,447,638.09 traded over the last 24 hours. More information can be found at http://apecoin.com/.',
#   'slug': 'apecoin-ape',
#   'logo': 'https://s2.coinmarketcap.com/static/img/coins/64x64/18876.png',
#   'subreddit': '',
#   'notice': '',
#   'tags': ['collectibles-nfts',
#    'content-creation',
#    'gaming',
#    'entertainment',
#    'dao',
#    'governance',
#    'metaverse',
#    'animoca-brands-portfolio'],
#   'tag-names': ['Collectibles & NFTs',
#    'Content Creation',
#    'Gaming',
#    'Entertainment',
#    'DAO',
#    'Governance',
# ...

# %%
len(["AVAX","QI","BTC","CSPR","CFG","CERE","CLV","ATOM","ETH","FTM","JOE","MINA","CAKE","PLGR","DOT","QUICK","BOO","TARA","RUNE","VEGA","XRP","SOL","DOGE","TRX","FLOW","EOS","AAVE","HNT","FTM","GRT","NEO","CEL","CRV","NEXO","TWT","CLV","GST","SAND","LRC","PLA","CHR","STG","XYO","ANT","ENJ","MVL","PMON","RFOX"])
# Out:
# 48
